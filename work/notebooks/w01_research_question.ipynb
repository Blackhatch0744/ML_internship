# %% [markdown]
# <a href="https://colab.research.google.com/github/Blackhatch0744/ML_internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Blackhatch0744/ML_assign1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# # **My Lane: Refresh/Content Opportunity Scoring**
#
# I want to investigate which content pages should be reviewed or refreshed first. This lane fits the available data because the provided dataset contains observable signals about search visibility, clicks, sessions, content age, freshness, and engagement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# !git clone https://github.com/Blackhatch0744/ML_internship.git
# Out:
# Cloning into 'ML_internship'...
# remote: Enumerating objects: 122, done.
# remote: Counting objects: 100% (122/122), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 122 (delta 35), reused 97 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (122/122), 1.86 MiB | 14.24 MiB/s, done.
# Resolving deltas: 100% (35/35), done.

# %%
# %cd ML_internship
# Out:
# /content/ML_internship/ML_internship/ML_internship

# %%
# !ls
# Out:
# AGENTS.md  DATA_USE.md	LICENSE    README.md	     SETUP.md	 work
# CLAUDE.md  docs		notebooks  requirements.txt  skills
# data	   GUIDE.md	outputs    scripts	     submission

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# # Research question
#
# Which content pages should be reviewed or refreshed first based on their observed search, traffic, content, and engagement signals?
#
# **Decision:** Decide which pages should receive priority for content review or refresh.
#
# **Action:** A content editor reviews the highest-priority pages and decides whether a refresh or any content modification is required.
#
# **Cost of a wrong call:** Prioritizing a page that does not need attention can waste limited editorial time, while failing to prioritize a page that could benefit from review can cause a potentially useful improvement opportunity to be missed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print(df.shape)
# Out:
# (30000, 44)

# %%
df.columns.tolist()
# Out:
# ['content_id',
#  'client_id',
#  'search_volume',
#  'competition',
#  'competition_level',
#  'cpc',
#  'content_type',
#  'main_intent',
#  'word_count',
#  'char_count',
#  'provider_used',
#  'model_used',
#  'impressions_90d',
#  'clicks_90d',
#  'pageviews_90d',
#  'sessions_90d',
#  'users_90d',
#  'engaged_sessions_90d',
#  'ai_sessions_90d',
#  'scroll_events_90d',
#  'days_with_impressions',
#  'days_with_sessions',
#  'impressions_last_30d',
#  'clicks_last_30d',
#  'sessions_last_30d',
#  'impressions_prev_30d',
#  'clicks_prev_30d',
#  'sessions_prev_30d',
#  'content_age_days',
#  'age_tier',
#  'age_tier_order',
#  'days_since_last_update',
#  'freshness_tier',
#  'word_count_tier',
#  'char_count_tier',
#  'ctr',
#  'avg_position',
#  'engagement_rate',
#  'scroll_rate',
#  'ai_traffic_pct',
#  'impression_tier',
#  'position_tier',
#  'trend_direction',
#  'trend_pct']

# %%
df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
df[[
    "search_volume",
    "impressions_90d",
    "clicks_90d",
    "sessions_90d",
    "content_age_days",
    "days_since_last_update",
    "ctr",
    "avg_position",
    "engagement_rate",
    "trend_direction"
]].describe(include="all")
# Out:
#         search_volume  impressions_90d    clicks_90d  sessions_90d  \
# count    27532.000000     30000.000000  30000.000000  30000.000000
# unique            NaN              NaN           NaN           NaN
# top               NaN              NaN           NaN           NaN
# freq              NaN              NaN           NaN           NaN
# mean       158.882391      5200.366300     16.097333     37.066633
# std       1518.270825     16838.019547     75.076958    107.069131
# min          0.000000         1.000000      0.000000      1.000000
# 25%          0.000000        81.000000      0.000000      2.000000
# 50%         10.000000       731.000000      1.000000      7.000000
# 75%         20.000000      3615.250000      7.000000     27.000000
# max      74000.000000    517715.000000   4178.000000   4345.000000
#
#         content_age_days  days_since_last_update           ctr  avg_position  \
# count        30000.00000            30000.000000  30000.000000   30000.00000
# ...

# %%
df["trend_direction"].value_counts()
# Out:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %%
print("Total pages:", len(df))
print("Median impressions (90d):", df["impressions_90d"].median())
print("Median sessions (90d):", df["sessions_90d"].median())
print("Pages with downward trend:", (df["trend_direction"] == "down").sum())
# Out:
# Total pages: 30000
# Median impressions (90d): 731.0
# Median sessions (90d): 7.0
# Pages with downward trend: 16262

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# I can identify observable patterns and associations between page characteristics, search performance, traffic, engagement, and content freshness. Also I can use these metrics to investigate which pages may be suitable for review or refresh.
#
# I cannot claim that a particular signal causes a change in traffic or rankings, that refreshing a page will definitely improve its performance, or that the analysis predicts Google's ranking decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
